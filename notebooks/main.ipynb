# %% [markdown]
# ## Set up dependencies

# %%
import os
import time

from dotenv import load_dotenv
import openai
import azure.cognitiveservices.speech as speechsdk

# %% [markdown]
# ## Set up environment variables

# %%
load_dotenv()
# Out:
# True

# %%
openai.api_type = os.getenv('OPENAI_API_TYPE')
openai.api_key = os.getenv('OPENAI_API_KEY') 
openai.api_base = os.getenv('OPENAI_API_BASE') 
openai.api_version = os.getenv('OPENAI_API_VERSION')

# %%
SPEECH_API_KEY = os.getenv('SPEECH_API_KEY')
SPEECH_API_REGION = os.getenv('SPEECH_API_REGION')

COMPLETIONS_MODEL = os.getenv('COMPLETIONS_MODEL')

# %%
def recognize_speech_from_file(filename):
    speech_api_key = SPEECH_API_KEY
    speech_api_region = SPEECH_API_REGION

    speech_config = speechsdk.SpeechConfig(subscription=speech_api_key, region=speech_api_region)
    audio_config = speechsdk.audio.AudioConfig(filename=filename)
    # Creates a speech recognizer using a file as audio input, also specify the speech language
    speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config,  audio_config=audio_config)
    global done 
    done = False
    global recognized_text_list 
    recognized_text_list=[]
    def stop_cb(evt: speechsdk.SessionEventArgs):
        """callback that signals to stop continuous recognition upon receiving an event `evt`"""
        print('CLOSING on {}'.format(evt))
        global done
        done = True

    def recognize_cb(evt: speechsdk.SpeechRecognitionEventArgs):
        """callback for recognizing the recognized text"""
        global recognized_text_list
        recognized_text_list.append(evt.result.text)
        print('RECOGNIZED: {}'.format(evt.result.text))

    # Connect callbacks to the events fired by the speech recognizer
    speech_recognizer.recognizing.connect(lambda evt: print('RECOGNIZING: {}'.format(evt)))
    speech_recognizer.recognized.connect(recognize_cb)
    speech_recognizer.session_started.connect(lambda evt: print('STT SESSION STARTED: {}'.format(evt)))
    speech_recognizer.session_stopped.connect(lambda evt: print('STT SESSION STOPPED {}'.format(evt)))
    speech_recognizer.canceled.connect(lambda evt: print('CANCELED {}'.format(evt)))
    # stop continuous recognition on either session stopped or canceled events
    speech_recognizer.session_stopped.connect(stop_cb)
    speech_recognizer.canceled.connect(stop_cb)

    # Start continuous speech recognition
    speech_recognizer.start_continuous_recognition()
    while not done:
        time.sleep(.5)

    speech_recognizer.stop_continuous_recognition()

    return recognized_text_list

# %% [markdown]
# ## Transcribe Interview to Text

# %%
text = recognize_speech_from_file("../data/sample.wav")
print(text)
# Out:
# STT SESSION STARTED: SessionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219)
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=1085df0af3bd4f83b1d73844b72d2fbc, text="hello mrs", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=ff499e596c544a9f9f7ce8437fafbc67, text="hello mrs steven", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=f4a1482f06b749ee824a154315c26c16, text="hello mrs stevens", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=42bc75d3e34f48279f2dd1b86df725c0, text="hello mrs stevens my name", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=0d9b2f2821d2431bb47cceaacc1ac050, text="hello mrs stevens my name is", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=127800f858b74b2d81f66964ec4aca09, text="hello mrs stevens my name is jane", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=ee45766dda3d40d384e646c18fca300f, text="hello mrs stevens my name is jane phillips", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=b9860c8206e343b0bed7db27ea81de6a, text="hello mrs stevens my name is jane phillips i'm", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=104c1399d93a42e792d7a728fe676320, text="hello mrs stevens my name is jane phillips i'm the personnel", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=573ab606a8de4a4a9372e36b28ba3ede, text="hello mrs stevens my name is jane phillips i'm the personnel director", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=076c4ebcb06b461c8b877f43810e5e7f, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=c9c232f1af7944ff860f0531d106aa6b, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to meet you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=3d345471feec448e8609ccb22d00dc6b, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to meet you please have a seat", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=2de1526d2e524855a4b9acd862048291, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to meet you please have a seat thank you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: Hello, Mrs. Stevens. My name is Jane Phillips. I'm the Personnel director. I'm pleased to meet you. Please have a seat. Thank you.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=e57649317b61467b852c417dac481c11, text="according to your", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=c2068fd5a91741fcb9dd8523a9b0cbc4, text="according to your res", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=63df89e56ea54d84892e889d5289d5dc, text="according to your resume you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=06f50d58d7774e3fab7a54aa8c43d555, text="according to your resume you have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=5364c2f467c5492bb547429251c37c19, text="according to your resume you have several", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=45d49eff21eb4ce5af229e9d308ba3d2, text="according to your resume you have several years of", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=4eb81aa017124d81854a8b3477727992, text="according to your resume you have several years of office", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=9b98e2f88a4f4d1fb80b3f0ac1d132b6, text="according to your resume you have several years of office experience", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: According to your resume, you have several years of office experience.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=2bad345a6ceb4f9ba8af9ab975916b12, text="yes i've", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=d7362ca72be24caca553bd3f27e47487, text="yes i've had over", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=c2237310b61b4e41b755e7ae501d2740, text="yes i've had over 10", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=8a4b19f640304bf48163ab9a4b7f14ca, text="yes i've had over 10 years", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=770d8e78407c4d9ab24d373d3caa6c0f, text="yes i've had over 10 years experience", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=c44601692f7d4c6b9a14b16761a6d155, text="yes i've had over 10 years experience tell", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=2acef2294e0e46cab9da92c86360feb4, text="yes i've had over 10 years experience tell me about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=1a2cdb492f8245b4baa76802cc0d79c0, text="yes i've had over 10 years experience tell me about your", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=1cf04a469d44494eb3e151ecd4e5320a, text="yes i've had over 10 years experience tell me about your qualific", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=b44768c9086b460697144999172f1b1f, text="yes i've had over 10 years experience tell me about your qualifications", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=f94f0399a9784c4493b2d0dab69e197b, text="yes i've had over 10 years experience tell me about your qualifications i can", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=635d655593ea4bd2adf1da3b1e33608b, text="yes i've had over 10 years experience tell me about your qualifications i can type", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=26fdbc0f5c0543f5ba0761ceb5ae9dca, text="yes i've had over 10 years experience tell me about your qualifications i can type over", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=dfba4371889849d58c5c5af6357d4832, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=3daa28e1ede44a00b35e916e90d4f5d1, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=86b88fd8465c41c0aae5d864bbf50b6d, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=71ed2c85b04d491eb39d87aeb4804adb, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=b3aabfaabb724c7ba65c3e191b7059f9, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=71bfce0dd5ce47719ca46b00372e4e71, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=f837cd2a4346448f88421c2749c28781, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=471d84b1f6ec4c4cbf666d933ab09fe0, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=0b3c4c820788462a869d393f7836ab43, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=b218b6645b534a169b2eb89187aa988a, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=2c74f58a00c744cbb13b4c5ad02b6aae, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=7d09a6939e9f44e380b9627cdb87eafd, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have excellent", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=6a819d7f4ea144659d84fd9ef69034c0, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have excellent interpersonal", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=dd3b4e98e7ec42c288207ba71dd11d0f, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have excellent interpersonal skills", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: Yes, I've had over 10 years experience. Tell me about your qualifications. I can type over 100 words per minute. I'm proficient in many computer programs. I have excellent interpersonal skills.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=6c07e4cddb6d4793b4e0b4da74c47efa, text="i am well", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=1dd2a9deeaa14534a0bab9060758c809, text="i am well organized", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=1ac33f5082e44ffbae70b356963046a2, text="i am well organized and i'm", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=9286c907609d441b9cfad978425803cb, text="i am well organized and i'm a", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=ed935edf3c39444f8de63089b7944cee, text="i am well organized and i'm a very fast learner", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=bef3522ac6514a429bda761ed4f3f2f9, text="i am well organized and i'm a very fast learner i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=d34f12d46c7646d2b5594c3f3dd2806e, text="i am well organized and i'm a very fast learner i see that", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=80007c277f5f4601ad0e36011250bde1, text="i am well organized and i'm a very fast learner i see that you have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=273f348be5b941ef9ce2c4a038ff1af0, text="i am well organized and i'm a very fast learner i see that you have excellent", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=0bbb459fb7584deea5bae2d2d35faf61, text="i am well organized and i'm a very fast learner i see that you have excellent references", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=75a8ad79c9dc466abe3bf4d3e641524f, text="i am well organized and i'm a very fast learner i see that you have excellent references do you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=93a5632e0dfe4564870b52e85389454a, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=d042def2e4e64a4b955077ba55bc3190, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=03dd8e5f7a5844e2aeddecc8d88843a1, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any questions", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=f0248a852f714fd1af721a63f0f72b9b, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any questions about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=9962a2eeac804fc598a833441b6b767e, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any questions about the position", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: I am well organized and I'm a very fast learner. I see that you have excellent references. Do you have any questions about the position?
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=710aae013db948e99f6a86b6bd4ea1ed, text="yes", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=20d375bc31a348789b28a0b884d90e42, text="yes what are", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=3db976bbdaef40c2a04bed8169374203, text="yes what are the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=939117e549714d1c8ab0e5f30cddf844, text="yes what are the respons", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=1dfecd41f19740ba86b294433340a116, text="yes what are the responsibilities", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=3fa4551f23ea49ccab58caeeb37fc3b6, text="yes what are the responsibilities in this", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=e15b741636b8484a9d5b3da7c4208ee8, text="yes what are the responsibilities in this position", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=9bbeba26690c43d8878f8a882e7e8148, text="yes what are the responsibilities in this position we're looking", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=4cbe109831f44e2ebc2d392d89b83c5c, text="yes what are the responsibilities in this position we're looking for", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=dc8f7a316cbb471588ec0fb02e12aa3d, text="yes what are the responsibilities in this position we're looking for someone", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=b5b47a73eeb042a2b6e184013480b44b, text="yes what are the responsibilities in this position we're looking for someone to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=ce48df9dd74c4235bedbb49c3480a366, text="yes what are the responsibilities in this position we're looking for someone to supervise", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=bfe34fdb04244256aaf1d888816fd98b, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=ff101db32ba24f359a71865e88b8d956, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=32fe59b8737540b7acef3003882fcd6a, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=a2b30b79bd57483d837991cdd1b02cd8, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=8ec2a77935fb457dba57a5458034c6f6, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspond", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=1fb4cbccb7de4041a34dcf0800971170, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=992a8300a7e64865814646ff218218be, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=39fe1e5a8f134227994a280dd7ddd765, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=02c93a777ee64d968adc4bf01afe69c7, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=b387c95d048b4250b33da3d57cd07ca9, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=becaf911ba4d4e7b80a327f7186b54bf, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=277f3bf4c8d9451f873fbcc74f459505, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=9790ab82ef7642f08508bf56e0c4b728, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=123839a4e9e242c994d470c359710c9c, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=fb71113f7e964ee18a8cf3706758ded4, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any super", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=7921c410e8e045969e1ac99e1e3e398c, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=f57cd36ccbd94173b2e59fe0ae026859, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=380ccf655d91412a967c6e7c05d7fa93, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=75c0a6d074c84491b691f47b36c2544b, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=a475254b57ea4ee4add6c014153fbb83, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i supervised", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=324c515f8f9a4a9aa249f808735ff5bb, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i supervised 3", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=10326190ffb44894b535fc3af82d2af9, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i supervised 3 administ", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=18cd858228a744abba6c3f511c2347f1, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i supervised 3 administrators", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=e0539866f18544d6bb73c554a41b0755, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i supervised 3 administrators in my", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=d943a346229848b2baf13a8e6dc62623, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i supervised 3 administrators in my last", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=54c8733dc6d148998276641bdd9c8223, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i supervised 3 administrators in my last position", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: Yes. What are the responsibilities in this position? We're looking for someone to supervise 2 office clerks, handle all the correspondence, arrange meetings and manage the front office. Have you had any supervisory experience? Yes, I supervised 3 administrators in my last position.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=b37db1d632324ace9cb17e6f9f033842, text="what are the office", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=d141edb1e5ab4a1690705117a91e4797, text="what are the office hours", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=358f342f577b425d82d19e23aeeb4ac8, text="what are the office hours mrs", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=4c00ae83278a4e1394c0c8547bd4a044, text="what are the office hours mrs phillips", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=37565967504549c3b54dd097b97f9e7d, text="what are the office hours mrs phillips 8:30", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=58ac96b14f8442bcb979b3a99744fbc9, text="what are the office hours mrs phillips 8:30 to 4:00", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=f464386f944243979277bc38a336c1c4, text="what are the office hours mrs phillips 8:30 to 4:30", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=427f4b7b860c45deaaa0110582927430, text="what are the office hours mrs phillips 8:30 to 4:30 with", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=edd731ca5f0b4a378bbe3c87933679db, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=6c7f8e7a91d641adac49f1f0d2aa2e2f, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=06df97a403a74f288008ec28d6de63eb, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=a1f8561349dc4c9696c2d0e60fb13426, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=f2ba6d5cc49e408a8d59ba1a40d27a34, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=7bb80e4d4b1a4e5aa570ae85da1eadb0, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=0941dc0b9a02499db7e51b36f7d88d42, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=ae152487cb2a4e7eae3d7d4d3974f881, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=095827bc16fd485b8149947cb8ad1939, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=246b0cd0a18b4364b61905383a43c820, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=038e18ad3cc149899e9f2d06ed8e3307, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=1bb2937b58b54a33bbac49898557a719, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=9df39dc8971148569695228279b969c0, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=d9fa0c81556f42c2b0a61eb9d2b34bc8, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=2d9cbe44f821449e85849a833351e689, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=df22e5f6f7354b54a5659896051f873a, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=fed1d86c4fbb4f7ba8214f7b3ebb0561, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=beaff84f11524da2ac45a2854b35bc13, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=2b07cdf000cf42f0826f9e9242e912e1, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=9e1ec1b7ade04fe8bf73132e0143356e, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=1e53121e6b574708bd5d40ec74065e24, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=95ccaeb3060644569e254f4864c9a8d8, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=61fe3a2ba6e0490a88e6de4cf2da0d32, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=53d17bc803464d67bf93282ae776b2a8, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=e5eff80b9c9942edbde9b709d396e206, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=9beae2aa4bda48af906ae105f23b8a79, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=f0bab4e19bfa45ed84e22f639e88aaf9, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we provide", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=a199e1611b1541acaa4554c84697805a, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we provide full", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=220f61b5a3db4d34b674f240221b4815, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we provide full medical", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=366a68dc90ef46ddb0c9d24b756802e9, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we provide full medical and", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=777dae74e05f40ddbba7dc0e9e1edeb7, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we provide full medical and dental", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=447a4e37b6fe4ef4804d76494550f553, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we provide full medical and dental coverage", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=afbe41d84a9248d8910737ad05480c83, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we provide full medical and dental coverage a pension", reason=ResultReason.RecognizingSpeech))
# ...
# RECOGNIZED: That's very generous. When is the position available?
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=33b60f764be140e18ffd5eddc160a671, text="we're hoping", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=9870fa219b81487fa85aa56a53191ab4, text="we're hoping the successful", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=9c0a36e852124063b34aef7e2b1b2e93, text="we're hoping the successful applic", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=1baee810173d43cfa27ff844e8e094ee, text="we're hoping the successful applicant", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=fa370083d8524cbdb12d7eb36eb42fb3, text="we're hoping the successful applicant can", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=9d1363a8df944af797076193f76c29cf, text="we're hoping the successful applicant can start at", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=ca0504db229f418a92b4ac515423451d, text="we're hoping the successful applicant can start at the beginning", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=38ab650fe8834a678eab9d52cb349cbd, text="we're hoping the successful applicant can start at the beginning of", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=c09fda2661334192a93ee54e4a614a32, text="we're hoping the successful applicant can start at the beginning of next month", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=df5003c8b8c2475fadbfc791b43aa825, text="we're hoping the successful applicant can start at the beginning of next month we'll", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=c9b2c1febb524f8293feecbef6f02e93, text="we're hoping the successful applicant can start at the beginning of next month we'll finish", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=206b6129345145f79f3b107306e607b8, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our inter", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=96468fb522274c5e9e5746275792e506, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tom", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=90c92127ae524b4480cfa38ba4354372, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=7a6ce2cb80464640925a8a1c5d76b759, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=41c3993c88194d0abaa01f8c98fd9781, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=acf91ee52ac04f71bdf6e6c3563e22b9, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a dec", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=5a9dedf2827f4c409697415159904143, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=5d94070245f64d5f87b11d960fef5e6c, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=412414bd3ad74cc68e571b6f7746617c, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=d1b64d8f769b4fb1a57cf78eb0514c3d, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=473bd635deea4012adee7ee01fe92912, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=38c33a6d2a054ef097dc1da3f7fbc05b, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=5a269b857ddd4e6d964a3d4cf2e2a7ad, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=c2851408f87b40569009ffb3e453d9f4, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=b612a8cbcbbc47b48c1d89dd6d83aef2, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=9b5500df3a02453fa634784ac019a92a, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=a9fa45a2cbe94f1692b49fd2654daa04, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=1417576f29e946edbac40ee2be916bb6, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=0176757aad80492e8c9e6c26ee6afd67, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=c37d17c1ab2f447595a01935acbe5aef, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=07020f04d9aa406c84c39442be6b66b0, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=cecfd5ece5964e1ab9292a96e4c1f6ec, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=a6932782dbcd4adc983594eb5fcc78c5, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in to see", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=87b658a0b8a249f0b9a21ddde2d7710c, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in to see us missus", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=ea4c55e773ca4ec095d36a985ea892f6, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in to see us missus stevens", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: We're hoping the successful applicant can start at the beginning of next month. We'll finish our interviews tomorrow and make a decision by the weekend. We'll contact you next week. Thank you very much. It's been a pleasure meeting you. I hope to hear from you soon. Thanks for coming in to see us, Missus Stevens.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=951dd34b851d4ff185ab525a3544c114, text="ellie", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: Ellie.
# CANCELED SpeechRecognitionCanceledEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=68397fc057614309aa988418017ef01c, text="", reason=ResultReason.Canceled))
# CLOSING on SpeechRecognitionCanceledEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219, result=SpeechRecognitionResult(result_id=68397fc057614309aa988418017ef01c, text="", reason=ResultReason.Canceled))
# STT SESSION STOPPED SessionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219)
# CLOSING on SessionEventArgs(session_id=2e8b44bf11d04d10a839423ed76f6219)
# ["Hello, Mrs. Stevens. My name is Jane Phillips. I'm the Personnel director. I'm pleased to meet you. Please have a seat. Thank you.", 'According to your resume, you have several years of office experience.', "Yes, I've had over 10 years experience. Tell me about your qualifications. I can type over 100 words per minute. I'm proficient in many computer programs. I have excellent interpersonal skills.", "I am well organized and I'm a very fast learner. I see that you have excellent references. Do you have any questions about the position?", "Yes. What are the responsibilities in this position? We're looking for someone to supervise 2 office clerks, handle all the correspondence, arrange meetings and manage the front office. Have you had any supervisory experience? Yes, I supervised 3 administrators in my last position.", 'What are the office hours, Mrs. Phillips? 8:30 to 4:30 with an hour off for lunch. What are your salary expectations, Missus Stevens, I expect to be paid the going rate for this type of position. Can you tell me about the benefits you offer? Yes. We provide full medical and dental coverage, a pension plan, and a three-week holiday per year.', "That's very generous. When is the position available?", "We're hoping the successful applicant can start at the beginning of next month. We'll finish our interviews tomorrow and make a decision by the weekend. We'll contact you next week. Thank you very much. It's been a pleasure meeting you. I hope to hear from you soon. Thanks for coming in to see us, Missus Stevens.", 'Ellie.']

# %% [markdown]
# ## Create prompt for listing interview questions

# %%
prompt = f"List all the interview questions \n\n{' '.join(text)}"

openai.Completion.create(
    engine="after-thought",
    prompt=prompt,
    temperature=0,
    max_tokens=300
)["choices"][0]["text"].strip(" \n")
# Out:
# "What are the responsibilities in this position? \n\nWe're looking for someone to supervise 2 office clerks, handle all the correspondence, arrange meetings and manage the front office. \n\nWhat are your salary expectations, Missus Stevens? \n\nI expect to be paid the going rate for this type of position. \n\nWhat are the office hours, Mrs. Phillips? \n\n8:30 to 4:30 with an hour off for lunch. \n\nCan you tell me about the benefits you offer? \n\nYes. We provide full medical and dental coverage, a pension plan, and a three-week holiday per year. \n\nDo you have any questions about the position? \n\nYes. \n\nWhen is the position available? \n\nWe're hoping the successful applicant can start at the beginning of next month. \n\nI see that you have excellent references. \n\nDo you have any questions about the position? \n\nYes. \n\nHave you had any supervisory experience? \n\nYes, I supervised 3 administrators in my last position. \n\nTell me about your qualifications. \n\nI can type over 100 words per minute. I'm proficient in many computer programs. I have excellent interpersonal skills. I am well organized and I'm a very fast learner. \n\nHello, Mrs. Stevens. \n\nMy name is Jane Phillips. I'm the Personnel director. I'm pleased to meet you. Please have a seat. Thank you. \n\nThanks for coming in to see us, Missus Stevens. \n\nEllie."
