# %% [markdown]
# ## Set up dependencies

# %%
import os
import time

from dotenv import load_dotenv
import openai
import azure.cognitiveservices.speech as speechsdk

# %% [markdown]
# ## Set up environment variables

# %%
load_dotenv()
# Out:
# True

# %%
openai.api_type = os.getenv('OPENAI_API_TYPE')
openai.api_key = os.getenv('OPENAI_API_KEY') 
openai.api_base = os.getenv('OPENAI_API_BASE') 
openai.api_version = os.getenv('OPENAI_API_VERSION')

# %%
SPEECH_API_KEY = os.getenv('SPEECH_API_KEY')
SPEECH_API_REGION = os.getenv('SPEECH_API_REGION')

# %%
def recognize_speech_from_file(filename):
    speech_api_key = SPEECH_API_KEY
    speech_api_region = SPEECH_API_REGION

    speech_config = speechsdk.SpeechConfig(subscription=speech_api_key, region=speech_api_region)
    audio_config = speechsdk.audio.AudioConfig(filename=filename)
    # Creates a speech recognizer using a file as audio input, also specify the speech language
    speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config,  audio_config=audio_config)
    global done 
    done = False
    global recognized_text_list 
    recognized_text_list=[]
    def stop_cb(evt: speechsdk.SessionEventArgs):
        """callback that signals to stop continuous recognition upon receiving an event `evt`"""
        print('CLOSING on {}'.format(evt))
        global done
        done = True

    def recognize_cb(evt: speechsdk.SpeechRecognitionEventArgs):
        """callback for recognizing the recognized text"""
        global recognized_text_list
        recognized_text_list.append(evt.result.text)
        print('RECOGNIZED: {}'.format(evt.result.text))

    # Connect callbacks to the events fired by the speech recognizer
    speech_recognizer.recognizing.connect(lambda evt: print('RECOGNIZING: {}'.format(evt)))
    speech_recognizer.recognized.connect(recognize_cb)
    speech_recognizer.session_started.connect(lambda evt: print('STT SESSION STARTED: {}'.format(evt)))
    speech_recognizer.session_stopped.connect(lambda evt: print('STT SESSION STOPPED {}'.format(evt)))
    speech_recognizer.canceled.connect(lambda evt: print('CANCELED {}'.format(evt)))
    # stop continuous recognition on either session stopped or canceled events
    speech_recognizer.session_stopped.connect(stop_cb)
    speech_recognizer.canceled.connect(stop_cb)

    # Start continuous speech recognition
    speech_recognizer.start_continuous_recognition()
    while not done:
        time.sleep(.5)

    speech_recognizer.stop_continuous_recognition()

    return recognized_text_list

# %% [markdown]
# ## Transcribe Interview to Text

# %%
text = recognize_speech_from_file("../data/sample.wav")
print(text)
# Out:
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=96d6ac2a50914553b955e66de581177b, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to meet you please have a seat thank you", reason=ResultReason.RecognizingSpeech))
# STT SESSION STARTED: SessionEventArgs(session_id=4097ecb73a00417b8de377161368419d)
# RECOGNIZED: Hello, Mrs. Stevens. My name is Jane Phillips. I'm the Personnel director. I'm pleased to meet you. Please have a seat. Thank you.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=2cdeca3e32744e8ab3b3cd8500eef762, text="according", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=8d970fc0f3154730a10b96e8d104ac0b, text="according to your", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=de74a35945ca426bb773dbc0b39f5b44, text="according to your res", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=2cb7c382d3b7414b9280e0392b7a11d7, text="according to your resume", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=faf5099dfbae4be481a0d8172716db5d, text="according to your resume you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=07a2d8245f7d4fdb97bbc3832c42adcb, text="according to your resume you have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=2a46e7b3dbb74e7cab7d1a9874bacab5, text="according to your resume you have several", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=ea8d04c6bb6243539c804d204c04f06b, text="according to your resume you have several years", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=fbb2230621614384b245c7f6da934ed0, text="according to your resume you have several years of", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=a5d6232f7cda4e939bea6192b57f62b0, text="according to your resume you have several years of office", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=aee70a3fe1d9497cb5839956fdb080ed, text="according to your resume you have several years of office experience", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=f0a6bc89cc19490cb210e7d7d0243b2a, text="hello mrs", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: According to your resume, you have several years of office experience.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=1fe9670dc47745f4a5042daf85a77f83, text="hello mrs stevens", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=7b4974e0b2784ca3b3b8df6802edbf96, text="hello mrs stevens my name", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=e2cb2cb80edc428a84986f2f3cc3ed9b, text="yes", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=163726b3d95b4b4c90f31e17a5c01aa6, text="hello mrs stevens my name is jane", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=f40bd7b04d50483b8bbf32faae159237, text="yes i've", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=1ffd45dace6f4521afc8c0e143ee3b69, text="hello mrs stevens my name is jane phillips i'm", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=2681eae1fffc479982e4c49f0a1c6aba, text="hello mrs stevens my name is jane phillips i'm the personnel", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=f6fa1ba913e74958a809b927db24490a, text="yes i've had over", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=5da5d5f9e5fd4c358bd8bbb1da75cb15, text="hello mrs stevens my name is jane phillips i'm the personnel director", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=35c6d66e78d74834ab35469b2c7e3f9a, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=f7a9c8f78dbb4ea2b928ff2037603ef4, text="yes i've had over 10", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=a2bde859bd5c418aba24f0bdb8fb012c, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to meet you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=25d4408fcb91426d9e72497f55f38f35, text="yes i've had over 10 years", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=39f48a2c120749e1bb7ce2d34a82cc3a, text="yes i've had over 10 years experience", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=8596613f751d45ec968ed820aa8d7ffa, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to meet you please have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=d722b8dd3c1240d99751125b8bbdd86a, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to meet you please have a seat", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=a700301961aa4bb1b8dd9355859a5187, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to meet you please have a seat thank", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=0632a2ba73e94385a22602ffd08c5972, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to meet you please have a seat thank you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=153b03eb407c46fbae5619309df984a4, text="yes i've had over 10 years experience tell", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=8f62c397ec8948e88956d6c7500c9216, text="yes i've had over 10 years experience tell me about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=650da17a94154ce29815534953065b97, text="yes i've had over 10 years experience tell me about your", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=0ce42af350d34f33ba348254fd6e6d5d, text="yes i've had over 10 years experience tell me about your qualific", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: Hello, Mrs. Stevens. My name is Jane Phillips. I'm the Personnel director. I'm pleased to meet you. Please have a seat. Thank you.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=869757cb3b1647f5bb705805584a44f9, text="according to your", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=f52f9fe145554f25ad8d1de269243d58, text="yes i've had over 10 years experience tell me about your qualifications", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=e4b3df26e01e47a0bdb980cbc05b6730, text="according to your res", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=b7d019fc08e14a5b9fc07295129ccf8a, text="according to your resume", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=22167cbc3fb84f26a5cc17993c92dfbd, text="according to your resume you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=e88c60d66c304443866e935f545d5e79, text="according to your resume you have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=70815806d6d142f2b4a90e82e4c8c155, text="according to your resume you have several", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=a25ae8b7f17f4b5392aa329fc11bc362, text="yes i've had over 10 years experience tell me about your qualifications i can", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=b7405b908c6940ca887f995a3428bd5f, text="according to your resume you have several years", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=28ac0ed92577414384a14ae4d31c71ec, text="yes i've had over 10 years experience tell me about your qualifications i can type", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=4263995c38b54207a3385358092d975b, text="according to your resume you have several years of", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=09ca302d6f7e4f04a9b25a3ca23ec0f6, text="yes i've had over 10 years experience tell me about your qualifications i can type over", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=39e2f80dd6e14ea7bf8c14747695c0cc, text="according to your resume you have several years of office", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=a0c87dd656e14cdda0a5a6a1c268e250, text="according to your resume you have several years of office experience", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=187450a29d6d4ad29bb7d358b4447a8e, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=5903250fd3e3496ca989c960f38c6993, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=83ae432c32134a5bbe5b63b1bc358722, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=ce36dfc74e644b01bef7dfcbca0b6d34, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=df5800ab01b44b188fd317f10403f680, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: According to your resume, you have several years of office experience.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=2f0baca33d3e443a8f3724de1940e5d9, text="yes i've", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=191d203f53af49978ccfda5db59d2404, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=ffdd624c8e634d14b3408f756492ba49, text="yes i've had over", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=f501ee0935a64131890c65832118d375, text="yes i've had over 10", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=32a35d215b954ecab14d69904f4ac680, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=a8ab5f92d3704723b0f6e31bd638a808, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=8135ab99ceb842c6b50715d514810b89, text="yes i've had over 10 years", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=7a0a1cf1396b425e8ff55a01cf6eb878, text="yes i've had over 10 years experience", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=152cf0d513fe4c85afcad4d27cbbe66a, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=831eb4b3545a4629823702c2599817ad, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=0d31046d3d004b7ca36bc1ab3bef0d90, text="yes i've had over 10 years experience tell", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=5274b67db2cd43b098131e23d9506ff0, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have excellent", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=134418fb58d448ab9235483dcf2b2428, text="yes i've had over 10 years experience tell me about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=91664eb4889a46b1bb41c62b72bc19e6, text="yes i've had over 10 years experience tell me about your", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=46ba59de70f64d11820d9a702078d381, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have excellent interpersonal", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=5ff82b01b0a84530a9c55b5434e972ee, text="yes i've had over 10 years experience tell me about your qualific", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=340d9b49375a42d08779970a53e63383, text="yes i've had over 10 years experience tell me about your qualifications", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=3b9a6226f5cf4fdebc86ceac096f5985, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have excellent interpersonal skills", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: Yes, I've had over 10 years experience. Tell me about your qualifications. I can type over 100 words per minute. I'm proficient in many computer programs. I have excellent interpersonal skills.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=d5e9a2b295094d6ebe32a7af63a7fd4a, text="yes i've had over 10 years experience tell me about your qualifications i can", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=373bd468736b4b56a105f75d7aebaa8e, text="i am well", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=61f81531e3de4216ab6f3c349619d34f, text="yes i've had over 10 years experience tell me about your qualifications i can type", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=1837002bd1cd493284a0f6d4fed63278, text="i am well organized", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=7158dacbeaca4b75b152cad3c06db9f1, text="yes i've had over 10 years experience tell me about your qualifications i can type over", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=17b07861fda848a9ad7d2807db22a589, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=83d88c32cdbe4b4898e94cd4633ca1ca, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=50bea411fd6348c6ae9374ba32e304fc, text="i am well organized and i'm", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=56cea52e1c1849da82893d7c0cf6a540, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=8cf43058a0634c58833126cf1bf262aa, text="i am well organized and i'm a", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=5c8292d014ce48e7beeddf98880bfd4d, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=78b293d5213f4b4da72bf95b888cb19b, text="i am well organized and i'm a very fast learner", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=6cae28be6a1c41449b2f3c7984970050, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=104fbc79a11c43c1b82b4430319c256e, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=da473e507212402d87ec8ff886d3ed6c, text="i am well organized and i'm a very fast learner i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=d5552ae4bd3c412e9a4af7ffaba78f17, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=b22e1840bbe44107a21ba348deb1cd7f, text="i am well organized and i'm a very fast learner i see that", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=0f33b5139b8a4f02bd866bdf13cbe3f8, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many comput", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=ce068dbe93884b57a142894f0f2b0ebf, text="i am well organized and i'm a very fast learner i see that you have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=2d74fe6c8fbe46beb207c89122f09082, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=06231004acfc4ace9810666bd85bad3e, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=50447270ef314bf5ac43c18ce58afee3, text="i am well organized and i'm a very fast learner i see that you have excellent", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=86348faecedb4454a09d97e7b9e2d7f7, text="i am well organized and i'm a very fast learner i see that you have excellent references", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=8fe13f12ba694403a9feb6a7dd32209a, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=962d8512867e47c2a24590c9807013f7, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=b7fec5b6517e4f54a4229a97200e6e33, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have excellent", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=21f66e0e408f48ecadc346f74da7b81d, text="i am well organized and i'm a very fast learner i see that you have excellent references do you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=b3897d22ae0045f181cde8b34c5355f1, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=cba6ee8526cc4fa78918834765aebfd7, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=0d342fd029154945a31da11080686247, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have excellent interpersonal", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=0fe9aa80f7b2459e96032299178c1eff, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any questions", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=b95cfd8117764d5daeef099b78d83a60, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have excellent interpersonal skills", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=a26886b32b9c4a5797e4d40da39654f1, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any questions about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=56a4376c5c6d4a1095e8cc824a38afe7, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any questions about the position", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: Yes, I've had over 10 years experience. Tell me about your qualifications. I can type over 100 words per minute. I'm proficient in many computer programs. I have excellent interpersonal skills.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=319f0a4015e0460c9b7d86cb76ec08ab, text="i am well", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=5db5c40a9789457a9ca4cc5754d63b00, text="i am well organized", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: I am well organized and I'm a very fast learner. I see that you have excellent references. Do you have any questions about the position?
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=9289226938e64a0f8ffd91eb1c876b5b, text="yes", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=36c0667c674d4d95aba562d4e8ade691, text="i am well organized and i'm", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=bb5bd4bc2a9a4267a7067446dc11347e, text="i am well organized and i'm a", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=4df7ba1f45c04fd08fc5caa31c9f4508, text="yes what", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=1b85347f39da4682ad0e303c6cec150e, text="i am well organized and i'm a very fast lear", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=d5fb4f471f534eda9e9318fad14b7386, text="i am well organized and i'm a very fast learner", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=e199769807b74b4c85f058c2db15f09e, text="yes what are", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=6eafc81ed78a41ca91128a99dcfc34df, text="yes what are the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=b5e04c5d6c2345ab9111f90c6fa6ae5a, text="yes what are the respons", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=6455ddd382194d9c90f882a2f029ba47, text="yes what are the responsibilities", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=9b6577901f6a4e64b48e1b4d1d50030e, text="yes what are the responsibilities in", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=d134528c1b684182919c633735aedba4, text="yes what are the responsibilities in this", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=d8a1775e831d487980843c31449abdc7, text="i am well organized and i'm a very fast learner i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=494a2b585ff84567acef1a90b58b6267, text="yes what are the responsibilities in this position", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=f3a112f0a39642f985635ce402a90fc7, text="i am well organized and i'm a very fast learner i see that", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=8920a20dfe974d6883d76f63312481fc, text="i am well organized and i'm a very fast learner i see that you have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=611f112ee59242bb8b308b1997062834, text="i am well organized and i'm a very fast learner i see that you have excellent", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=c52e82ffac3d49aeabe64ee8335c6358, text="i am well organized and i'm a very fast learner i see that you have excellent references", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=9c79a267898e4ab799cbb4e64ea1ec26, text="yes what are the responsibilities in this position we're looking", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=b9b71a7372f4487eb2222b4e1f04e64f, text="yes what are the responsibilities in this position we're looking for", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=949f1a9b29364786b4b7146eb861bf71, text="yes what are the responsibilities in this position we're looking for someone", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=0670ef34dead4c978d77465a3843b201, text="yes what are the responsibilities in this position we're looking for someone to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=6e1fe19bdfd94552ab5d61b5c67413da, text="i am well organized and i'm a very fast learner i see that you have excellent references do you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=2154d6e7af554d79808f3c9b5a37da9a, text="yes what are the responsibilities in this position we're looking for someone to supervise", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=4564f6b4eb2e49329fd5978f88265a56, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=a1c33a80d858480a9175558b8d18bc8f, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=32f7af2f54d34376a016066f755d4866, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any questions", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=cfe08eb8200c4df8a2fd1e82063c3473, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=be2769e09e214bde80747348eb476891, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any questions about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=3f3b9e78c57247e2b962a6ab89ad1297, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any questions about the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=a30a4c6e328d4c5c8b88a72e0fc0a7a4, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any questions about the position", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=a3c48c13bdee4c5c8d527393ceff87dd, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=77194705931748018308b79b41791a4d, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=4e1f125170bf4740b983f653168c88c9, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=c295aebfc68d4cb7b821fe9430d3a480, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the cor", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=4babb94dc5cd48a582d4e3f7057280ca, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspond", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=221da13a51794891b1c6a55e258638b3, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: I am well organized and I'm a very fast learner. I see that you have excellent references. Do you have any questions about the position?
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=79b929705fef4fd0b3936ef6361d4d42, text="yes what", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=68c2f062573f45e2b907722816055ae6, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=9f7e56c977ef4182acbdd9395b0da861, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=e2e13a8d3f784c65b40a691be47087c4, text="yes what are", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=39122ff7cdb84935a626b4b3a78a4d7a, text="yes what are the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=43c291ba2c704d5b826387d4d3a744d8, text="yes what are the respons", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=d84b5f09d19e44ffba45b6c2b099e602, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=c843e33107b041aa9d950e1820111668, text="yes what are the responsibilities", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=8f111a354db343e7b7e7fd0847f515ae, text="yes what are the responsibilities in this", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=8431fd882fca49f09e0814b96d19f8be, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=4398fe115aac4bd18785ea115a55d2db, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=eda20f5f46c84933aa4a80e766fd7a35, text="yes what are the responsibilities in this position", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=73408285318e415ca172d64e5caf328c, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=3ef89a66e58d420b9416f22406a1fd5a, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=9a87975012ae4b2dbe1df99c6027d3db, text="yes what are the responsibilities in this position we're looking", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=4e7167f6520d4953bd0a9106443ba06d, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=24b3673e10cb457397c3bd4588db002b, text="yes what are the responsibilities in this position we're looking for", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=769ab5810c9c4ec89dd689cfc068f8f8, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any", reason=ResultReason.RecognizingSpeech))
# ...
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=5bdfa626ae8649a5a6d7989276b4b96e, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=fb94125ea5e14f10be564a5bd16b363e, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=a9ced3e2a850426d9324e45fca8f7359, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=b4b95dee0c02491ab93c0bab5d25d01c, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in to see", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=c5d7a672585d417f8ac37d5f4db27e26, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in to see us missus", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=0b6bf27da3114dc7894b359f10bc4f59, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in to see us missus stevens", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=4d3b94df64f24293b35fb3225fe48146, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=ea5955b214514ffba9c41aef0d63e947, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=59e07e97438a42c6a3ab2e60b5d2a657, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: We're hoping the successful applicant can start at the beginning of next month. We'll finish our interviews tomorrow and make a decision by the weekend. We'll contact you next week. Thank you very much. It's been a pleasure meeting you. I hope to hear from you soon. Thanks for coming in to see us, Missus Stevens.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=2f839e4113dd447d80cac80b1ee48baf, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=eca960c08d1d43438ede0798dcee85c5, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=c1bcc43e7dd547cb889e7a49047953b4, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=6177f086fce745fab7bee31c8a59c303, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=72f0a2e37552425fb802390fa4147e31, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=5614eb33bd2f4ce5b12bf3907c28b174, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=63ce4e4e60454810ab29bce7c0af1d8d, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=bd8cb2dfe4c74a9dab686fc272c2ce28, text="ellie", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: Ellie.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=98e9f4cb40c9495c977d192c8e17ce40, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=216a5fa0482346978b0564e797a33e00, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=d3ccbfc71a3643bda6f82922adf99369, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=8c3cfcf3b5824a6c8585ab17671d946a, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=f63c6d8dfbda4c6387763c8ab264ac53, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=5c107ca553b44739b61a76c96bf8b880, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in to see", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=f8327b8ee77e4825b38adaadcc1874d3, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in to see us missus", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=6722ac6c831c44fd9fb16781ae0c6b55, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in to see us missus stevens", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: We're hoping the successful applicant can start at the beginning of next month. We'll finish our interviews tomorrow and make a decision by the weekend. We'll contact you next week. Thank you very much. It's been a pleasure meeting you. I hope to hear from you soon. Thanks for coming in to see us, Missus Stevens.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=4097ecb73a00417b8de377161368419d, result=SpeechRecognitionResult(result_id=1c9f63a9e7ad422e87409c9a7c10e6e3, text="ellie", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: Ellie.
# CANCELED SpeechRecognitionCanceledEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=0ab78e1a5aa9494282bc5c69e34a391d, text="", reason=ResultReason.Canceled))
# CLOSING on SpeechRecognitionCanceledEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d, result=SpeechRecognitionResult(result_id=0ab78e1a5aa9494282bc5c69e34a391d, text="", reason=ResultReason.Canceled))
# STT SESSION STOPPED SessionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d)
# CLOSING on SessionEventArgs(session_id=8a2488e45e8b4a3ca1d42d32aaab594d)
# STT SESSION STOPPED SessionEventArgs(session_id=4097ecb73a00417b8de377161368419d)
# CLOSING on SessionEventArgs(session_id=4097ecb73a00417b8de377161368419d)
# ["Hello, Mrs. Stevens. My name is Jane Phillips. I'm the Personnel director. I'm pleased to meet you. Please have a seat. Thank you.", 'According to your resume, you have several years of office experience.', "Hello, Mrs. Stevens. My name is Jane Phillips. I'm the Personnel director. I'm pleased to meet you. Please have a seat. Thank you.", 'According to your resume, you have several years of office experience.', "Yes, I've had over 10 years experience. Tell me about your qualifications. I can type over 100 words per minute. I'm proficient in many computer programs. I have excellent interpersonal skills.", "Yes, I've had over 10 years experience. Tell me about your qualifications. I can type over 100 words per minute. I'm proficient in many computer programs. I have excellent interpersonal skills.", "I am well organized and I'm a very fast learner. I see that you have excellent references. Do you have any questions about the position?", "I am well organized and I'm a very fast learner. I see that you have excellent references. Do you have any questions about the position?", "Yes. What are the responsibilities in this position? We're looking for someone to supervise 2 office clerks, handle all the correspondence, arrange meetings and manage the front office. Have you had any supervisory experience? Yes, I supervised 3 administrators in my last position.", "Yes. What are the responsibilities in this position? We're looking for someone to supervise 2 office clerks, handle all the correspondence, arrange meetings and manage the front office. Have you had any supervisory experience? Yes, I supervised 3 administrators in my last position.", 'What are the office hours, Mrs. Phillips? 8:30 to 4:30 with an hour off for lunch. What are your salary expectations, Missus Stevens, I expect to be paid the going rate for this type of position. Can you tell me about the benefits you offer? Yes. We provide full medical and dental coverage, a pension plan, and a three-week holiday per year.', "That's very generous. When is the position available?", 'What are the office hours, Mrs. Phillips? 8:30 to 4:30 with an hour off for lunch. What are your salary expectations, Missus Stevens, I expect to be paid the going rate for this type of position. Can you tell me about the benefits you offer? Yes. We provide full medical and dental coverage, a pension plan, and a three-week holiday per year.', "That's very generous. When is the position available?", "We're hoping the successful applicant can start at the beginning of next month. We'll finish our interviews tomorrow and make a decision by the weekend. We'll contact you next week. Thank you very much. It's been a pleasure meeting you. I hope to hear from you soon. Thanks for coming in to see us, Missus Stevens.", 'Ellie.', "We're hoping the successful applicant can start at the beginning of next month. We'll finish our interviews tomorrow and make a decision by the weekend. We'll contact you next week. Thank you very much. It's been a pleasure meeting you. I hope to hear from you soon. Thanks for coming in to see us, Missus Stevens.", 'Ellie.']
