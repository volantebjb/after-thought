# %% [markdown]
# ## Set up dependencies

# %%
import os
import time

from dotenv import load_dotenv
import openai
import azure.cognitiveservices.speech as speechsdk

# %% [markdown]
# ## Set up environment variables

# %%
load_dotenv()
# Out:
# True

# %%
openai.api_type = os.getenv('OPENAI_API_TYPE')
openai.api_key = os.getenv('OPENAI_API_KEY') 
openai.api_base = os.getenv('OPENAI_API_BASE') 
openai.api_version = os.getenv('OPENAI_API_VERSION')

# %%
SPEECH_API_KEY = os.getenv('SPEECH_API_KEY')
SPEECH_API_REGION = os.getenv('SPEECH_API_REGION')

COMPLETIONS_MODEL = os.getenv('COMPLETIONS_MODEL')

# %%
def recognize_speech_from_file(filename):
    speech_api_key = SPEECH_API_KEY
    speech_api_region = SPEECH_API_REGION

    speech_config = speechsdk.SpeechConfig(subscription=speech_api_key, region=speech_api_region)
    audio_config = speechsdk.audio.AudioConfig(filename=filename)
    # Creates a speech recognizer using a file as audio input, also specify the speech language
    speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config,  audio_config=audio_config)
    global done 
    done = False
    global recognized_text_list 
    recognized_text_list=[]
    def stop_cb(evt: speechsdk.SessionEventArgs):
        """callback that signals to stop continuous recognition upon receiving an event `evt`"""
        print('CLOSING on {}'.format(evt))
        global done
        done = True

    def recognize_cb(evt: speechsdk.SpeechRecognitionEventArgs):
        """callback for recognizing the recognized text"""
        global recognized_text_list
        recognized_text_list.append(evt.result.text)
        print('RECOGNIZED: {}'.format(evt.result.text))

    # Connect callbacks to the events fired by the speech recognizer
    speech_recognizer.recognizing.connect(lambda evt: print('RECOGNIZING: {}'.format(evt)))
    speech_recognizer.recognized.connect(recognize_cb)
    speech_recognizer.session_started.connect(lambda evt: print('STT SESSION STARTED: {}'.format(evt)))
    speech_recognizer.session_stopped.connect(lambda evt: print('STT SESSION STOPPED {}'.format(evt)))
    speech_recognizer.canceled.connect(lambda evt: print('CANCELED {}'.format(evt)))
    # stop continuous recognition on either session stopped or canceled events
    speech_recognizer.session_stopped.connect(stop_cb)
    speech_recognizer.canceled.connect(stop_cb)

    # Start continuous speech recognition
    speech_recognizer.start_continuous_recognition()
    while not done:
        time.sleep(.5)

    speech_recognizer.stop_continuous_recognition()

    return recognized_text_list

# %%
import Levenshtein

def calculate_wer(reference, hypothesis):
    # Tokenize the reference and hypothesis into words
    ref_tokens = reference.split()
    hyp_tokens = hypothesis.split()

    # Calculate Levenshtein distance
    distance = Levenshtein.distance(reference, hypothesis)

    # Calculate WER
    wer = distance / len(ref_tokens)

    return wer

def test_speech_to_text_conversion(audio_file_path, ground_truth):
    # Call speech-to-text conversion function and get the transcribed text
    transcribed_text = recognize_speech_from_file(audio_file_path)
    print(transcribed_text)

    # Convert the transcribed text list into a single string
    transcribed_text_str = ' '.join(transcribed_text)
    print(transcribed_text_str)

    # Calculate WER
    wer = calculate_wer(ground_truth, transcribed_text_str)

    return wer

# %%
with open('../data/ground-truth.txt', 'r') as file:
    ground_truth = file.read()

audio_file_path = "../data/sample.wav" 


wer_result = test_speech_to_text_conversion(audio_file_path, ground_truth)
print(f"Word Error Rate (WER): {wer_result * 100:.2f}%")
# Out:
# STT SESSION STARTED: SessionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf)
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=546691099a484498a8662c80c222167d, text="hello mrs steven", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=7f991ba634774fee812974d186e4cd7e, text="hello mrs stevens", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=92c7eb16c2be410e9223676b7e087cfc, text="hello mrs stevens my name is", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=40f5fbdcdf9449a9bce2a78423bc478d, text="hello mrs stevens my name is jane", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=6fd7eecbca824922a1418092db044ecc, text="hello mrs stevens my name is jane phillips", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=ed814e0d973e439b8b6c390dbbb72a43, text="hello mrs stevens my name is jane phillips i'm the personnel", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=a9a2a7814a634523ab545bcc7636be8d, text="hello mrs stevens my name is jane phillips i'm the personnel director", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=adee54c6b2494cbdb4d4e4057554ab70, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=2f6a49bd6bd44fc39d06cb7f4e97e78f, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to meet you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=864ad514470d49f484e4cdf62c243b64, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to meet you please have a", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=7e846fa7b8594a91a16e235ca4e7ac43, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to meet you please have a seat", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=aba2a4bd199e42cf8ac70abeeffa5ed8, text="hello mrs stevens my name is jane phillips i'm the personnel director i'm pleased to meet you please have a seat thank you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: Hello, Mrs. Stevens. My name is Jane Phillips. I'm the Personnel director. I'm pleased to meet you. Please have a seat. Thank you.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=226e4d8f46f34183b44e11a7543f0c90, text="according", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=15921df45e204e9ca753ea2cf42c76c3, text="according to your", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=7b5f7f93cfc046e1816c02b372894381, text="according to your res", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=15fee4de613d46069197f26f50040e12, text="according to your resume", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=29b79b93f3874183b26f5e728b29bb4f, text="according to your resume you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=ae13a18568e442649f8125403ec31ab2, text="according to your resume you have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=1388d833f0004f67bb78e53662f93905, text="according to your resume you have several", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=81246b60fe88450ebe6394ffd73e9468, text="according to your resume you have several years", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=9976ff40fe684842adb000e65c376621, text="according to your resume you have several years of", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=703fce8b5f4442c6b5e859874e30c64f, text="according to your resume you have several years of office", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=89cd04011b4d483e8457867cfa031e0a, text="according to your resume you have several years of office experience", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: According to your resume, you have several years of office experience.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=39f9d4dcedc8487c90a26ec713398103, text="yes", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=aaa8fadd086246df9385135842743e5d, text="yes i've", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=60c00799a2454e779b95c289636de251, text="yes i've had over", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=9fe8170e96744c598ee58100269d721d, text="yes i've had over 10", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=e1a1f247552846d688f9f02407ea06b4, text="yes i've had over 10 years", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=9fee0889620d4756aa285edf6f0c5683, text="yes i've had over 10 years experience", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=7b3e39663742415a8ec268ebf8afc092, text="yes i've had over 10 years experience tell", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=ee75b63999e040c386d371e9328f7967, text="yes i've had over 10 years experience tell me about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=8350fbc89ad64f50a9ee402c0ca849a4, text="yes i've had over 10 years experience tell me about your", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=d0fecab8ff6f4f7380e3a55484062c32, text="yes i've had over 10 years experience tell me about your qualific", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=2ddffa70658c4f4b9dd640f0d8860dd5, text="yes i've had over 10 years experience tell me about your qualifications", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=f3f7101eabed4f00a372ec28f1836f49, text="yes i've had over 10 years experience tell me about your qualifications i can", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=cc7034978631438e89954a3c6bfdef85, text="yes i've had over 10 years experience tell me about your qualifications i can type", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=0b9ffacfa487439daa3f58c5c1364fad, text="yes i've had over 10 years experience tell me about your qualifications i can type over", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=51c0a3c52d594ab59665083b6bc0a170, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=741b217980c14fb198a501e068901047, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=8778300bd7364d26a8d3929d04f12752, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=d293df51ab124ad7ba17121d81d72e44, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=ff3879f6a7824965a67134b733829255, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=6dea8eadd91a4beb98aaed0ca80881fe, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=78b753fa764b49caa3b81e9330ad88ed, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=f76799db4e43419eaa09591d44b0091c, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=81a8950f9d624de8aa0a77897820cdd6, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=be0e2b6847524606a8f4716c99d9f0c3, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=d28290a03efa4318893dfc65a658942b, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have excellent", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=3185c9aae57b48d399c2cc8971635b85, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have excellent interpersonal", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=b2f5d66663a34970a6f9ac0e572596db, text="yes i've had over 10 years experience tell me about your qualifications i can type over 100 words per minute i'm proficient in many computer programs i have excellent interpersonal skills", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: Yes, I've had over 10 years experience. Tell me about your qualifications. I can type over 100 words per minute. I'm proficient in many computer programs. I have excellent interpersonal skills.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=d9d2cc2abdfe4e1c9f306cc921f86688, text="i am well", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=350f79c99de5479fa062f57e8bd8e324, text="i am well organized", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=c2157769eaab4314b4c6772969015817, text="i am well organized and i'm", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=2c2f080bc4ae4ceda544b20b75632ede, text="i am well organized and i'm a", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=40032a0ce2f744fe8614653722d13fe7, text="i am well organized and i'm a very fast learner", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=f30c354e10b9429794882ed38573ce19, text="i am well organized and i'm a very fast learner i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=e7f29fbdf15d45b6bd690f0bc5914e58, text="i am well organized and i'm a very fast learner i see that", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=16d608b211d44779b3efd7ad566f784f, text="i am well organized and i'm a very fast learner i see that you have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=1d5f33467afd4efc8bc139714307a34c, text="i am well organized and i'm a very fast learner i see that you have excellent", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=828affc0125e49b59d022ba58373df13, text="i am well organized and i'm a very fast learner i see that you have excellent ref", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=0bb4c169148245c49e113e41137a32e6, text="i am well organized and i'm a very fast learner i see that you have excellent references", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=960b860797b443d3b3a056fda46e08ba, text="i am well organized and i'm a very fast learner i see that you have excellent references do you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=4efa321129f34864a13083a3b9b6b79f, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=5f0f2d00e2b346a8902ae24d64b43db6, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=b2a23efe22bb4aefad4a0c61bd178a8b, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any questions", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=df589ddafb1c46cd8511a55d4b50a473, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any questions about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=d26a00930b9e4f89b95b271440829e4b, text="i am well organized and i'm a very fast learner i see that you have excellent references do you have any questions about the position", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: I am well organized and I'm a very fast learner. I see that you have excellent references. Do you have any questions about the position?
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=1e8f28b6afe04deba8feced081ca9749, text="yes", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=830ca2172c804149ad8f777070d1ea13, text="yes what", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=0c59daa0b32b4ae1982e2fe957ce2d86, text="yes what are", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=d353f080a83a47fa81479d4c50388d84, text="yes what are the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=8726895b3f124444baf902207699d418, text="yes what are the respons", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=a09bd23a0e624580919c4e81f26fada7, text="yes what are the responsibilities", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=46143edc8e6e49099ccccde9a069b4fe, text="yes what are the responsibilities in this", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=7b2bd307a86e4b82ba1ba7f02120080e, text="yes what are the responsibilities in this position", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=2228a5bc1b074649b85810d267dc14ca, text="yes what are the responsibilities in this position we're looking", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=4c315f4568e54730bfbf636047e65f12, text="yes what are the responsibilities in this position we're looking for", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=59deac9723b64416808f293db91d1672, text="yes what are the responsibilities in this position we're looking for someone", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=9a6019b163e64e4b8ad07d25d51e1599, text="yes what are the responsibilities in this position we're looking for someone to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=95ea592e12b64c25b3d8861dc225c928, text="yes what are the responsibilities in this position we're looking for someone to supervise", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=a8645313e178479da70c830b7a0878ce, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office cl", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=848e238dd7d847c1940815c8f3f9cb31, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=092d2a1d043c486a9cf3c19bc89b221f, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=9857237ebe90438e89f61f581d4f0ab6, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=689419fdfb86407783df7475594ae604, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspond", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=e385927e6ac24c17af1617f700e5e116, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=26b169902fc64a62ac8a64e07a72288f, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=19092bd4c35b45c481f7e9d60b8a38bc, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=c1700265badf46459f95d35b778d34b2, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=3d876b5c63d3461a8849a92179c2ab69, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=dbc94a30b11349f7833624a7bc34d6fc, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=bedcb0f9f64b43beac09c182e8231685, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=b214c6a91fef4f95903671ec7884aec7, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=9c1b3acccbdb454c8ebad6c590d718db, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=5a012b99455a4b97a1ea30eb245e29cd, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any super", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=4c72f62d32934cb7b38ad8931c20d899, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=168126e2e7e24bf1aaf8dce84060d934, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory exper", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=7897932d80c04b31a7852362d6b4b8b6, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=dd4fb190b3a341d69b3f47fc669586ce, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=86f2667fd9b4493bba14191e1e7e1692, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=01d789dd49ff408dbced5f7923b1fdc5, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i supervised", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=f78d7b1680ce46bb8e3e1648afa3b3e3, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i supervised 3", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=87bb34b56a1f468eabae84086b60ea0f, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i supervised 3 administ", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=36744a904191414e8994c65d138fa19a, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i supervised 3 administrators", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=b313cb4428a54b4b90435c83e9730175, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i supervised 3 administrators in my last", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=3ea7f31d2e0e4600b26637b419e65dbb, text="yes what are the responsibilities in this position we're looking for someone to supervise 2 office clerks handle all the correspondence arrange meetings and manage the front office have you had any supervisory experience yes i supervised 3 administrators in my last position", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: Yes. What are the responsibilities in this position? We're looking for someone to supervise 2 office clerks, handle all the correspondence, arrange meetings and manage the front office. Have you had any supervisory experience? Yes, I supervised 3 administrators in my last position.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=9c8c05d2c2cc402a97f3abc0051ec27b, text="what", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=958cc41bb7534441a9bf67e90fd7a3e2, text="what are the office", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=dfdfb4b728de4e328fda92512a388a15, text="what are the office hours", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=e5fb313108b94c61a9c1778dbd8dc3af, text="what are the office hours mrs", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=e4755994ab794dd781c2cacd5af3551e, text="what are the office hours mrs phillips", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=0c03683c1f3f4db1a18a4d9bffb92e30, text="what are the office hours mrs phillips 8:30", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=29555a6980bf432fb8689358762ada53, text="what are the office hours mrs phillips 8:30 to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=34c1bfe08544455895333fb5cbbaf340, text="what are the office hours mrs phillips 8:30 to 4:00", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=3fbc2650e8e144548fc3a6587ef472e0, text="what are the office hours mrs phillips 8:30 to 4:30", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=5f2f14a9c80d42d3befb344d390fde75, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=c2c32e8c9d514ab8b2705d05c769e6c7, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=90232cdd7dc34a969347a9152fc90018, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=50353ff759e846a399350d364857a2b7, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=21376f2047d947d9805285e0d13e26bd, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=4bc0bdfd33134409872d6d2014121c90, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=07bfea8448a643c2abd4b14825376145, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=70727482f7d2485a96603546584ca477, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=37243de4acdb48079e1b22c49974cd32, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=5fda13f50bb5487eaf2b047bdbb3238d, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=06c6032c862848119495aebccf39569e, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=b6a95dcdad7a4772a8b681d34dc8bf58, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=de482e22861e4a9685e28891b94858e7, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=a71c1817cb924e55a27d243c969610aa, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=4cf68e8c01cf4984a0cc896bd1ffdb05, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=3d1ac6079ca148ac8d3755eb195a69f9, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=05a2024016e9467488013c5d78148b4f, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=fce2f339b8fa415593d0616df9d80553, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=9643afd7108e4e54bcca4329e4fb7060, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=1e07d8e01efd42e4a3926a99e354cb8f, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=ca33a177adc842c6a84abc19b974412b, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=31f799f3da3d422b9f27208b91b2b1e0, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=68a24b5096574dedb8d9553be8fdef80, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=a7e45a87ce4146c7b40e15cd5c7e3e15, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=1a33261b960245d083e161d7f83c73cc, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=e6a23738f7544964a2d23ee423b443a2, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=aa2fed242e3a4e30a2f45c33b190943e, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=67fbe8a9b0134e3badba9bd1e71bc82c, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we provide", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=2f66eac9b2cc4a3ab12111c3e31d02f1, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we provide full", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=e596a02e7e9d48dd9253083ffe6f840c, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we provide full medical", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=2b78931211af41b490b23091b816080b, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we provide full medical and dental", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=b5ffb1833c7c4f3f80ca410926ae0527, text="what are the office hours mrs phillips 8:30 to 4:30 with an hour off for lunch what are your salary expectations missus stevens i expect to be paid the going rate for this type of position can you tell me about the benefits you offer yes we provide full medical and dental coverage", reason=ResultReason.RecognizingSpeech))
# ...
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=67ae1218331d40439db7da585f536f31, text="we're hoping the successful applicant can start at the beginning of", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=7ef1dfb9fbc5478a82bcc2929b6ba84f, text="we're hoping the successful applicant can start at the beginning of next month", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=f497a68be9734356b93b56a6ac4d6f8c, text="we're hoping the successful applicant can start at the beginning of next month we'll", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=f3e7eb9e6fa44fae89730d1e7b317706, text="we're hoping the successful applicant can start at the beginning of next month we'll finish", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=af2358c1dec54265ba4b145b89ca9300, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interview", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=504078b5ff874cf7afb5139acba620c5, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=ad40a403f32847fba3d244c619df8f26, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=ee25a5cd46bb46beb85cfb38f7cc32f6, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=2e8e2a68c497469baa04a39ba0b2d21e, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=7267a28c9cf0430d9fd80179fea2db47, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=73097ff1eac54bc6ac3e227567351b39, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=fa9982f0fb304872b74053b6915e16d7, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=49452d0e4c9c4d07852282de691a7eaa, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=88c544808739422e8ba91728ceaaadbf, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=aa55efd6339f4049803356bcfb2ca32d, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=be7df803ec5149b6ac3c57e56a982bdf, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=a44055c8705947d98acdc0372de0b1a7, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=f69878bd2ab9432ca09213781fe46ecd, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=1bf17702888d472bac2401307e7cde28, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=a460d8292d504b3bb1e793b465c8c5ed, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=8185bb26a6944c699ac3eaf89c416de0, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=dc353c28429449c4bba4000acc3f130e, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=5fdbbdd8a7c34f679906e7c688eb4e9b, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=7d5f42f12b7b451fb464d742eff8eb1e, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=35d5069d9961484abc654c1d60f36671, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=a7a8357368654fb791fdbe9041c738d2, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=2feb660459de46db9004210bdf6c8949, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in to see", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=7a3b3b1af2ce4a7fb6f1315a8c55f208, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in to see us missus", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=d9bf5f5c7a6b4a6ebb83ade773ed1602, text="we're hoping the successful applicant can start at the beginning of next month we'll finish our interviews tomorrow and make a decision by the weekend we'll contact you next week thank you very much it's been a pleasure meeting you i hope to hear from you soon thanks for coming in to see us missus stevens", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: We're hoping the successful applicant can start at the beginning of next month. We'll finish our interviews tomorrow and make a decision by the weekend. We'll contact you next week. Thank you very much. It's been a pleasure meeting you. I hope to hear from you soon. Thanks for coming in to see us, Missus Stevens.
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=1ae385bbee90425f92998719e05ed76e, text="ellie", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: Ellie.
# CANCELED SpeechRecognitionCanceledEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=53377c8f85ef4c14bd8580c38bd5f12b, text="", reason=ResultReason.Canceled))
# CLOSING on SpeechRecognitionCanceledEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf, result=SpeechRecognitionResult(result_id=53377c8f85ef4c14bd8580c38bd5f12b, text="", reason=ResultReason.Canceled))
# STT SESSION STOPPED SessionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf)
# CLOSING on SessionEventArgs(session_id=247e995baedf4a0bb7f0ea28c0b53faf)
# ["Hello, Mrs. Stevens. My name is Jane Phillips. I'm the Personnel director. I'm pleased to meet you. Please have a seat. Thank you.", 'According to your resume, you have several years of office experience.', "Yes, I've had over 10 years experience. Tell me about your qualifications. I can type over 100 words per minute. I'm proficient in many computer programs. I have excellent interpersonal skills.", "I am well organized and I'm a very fast learner. I see that you have excellent references. Do you have any questions about the position?", "Yes. What are the responsibilities in this position? We're looking for someone to supervise 2 office clerks, handle all the correspondence, arrange meetings and manage the front office. Have you had any supervisory experience? Yes, I supervised 3 administrators in my last position.", 'What are the office hours, Mrs. Phillips? 8:30 to 4:30 with an hour off for lunch. What are your salary expectations, Missus Stevens, I expect to be paid the going rate for this type of position. Can you tell me about the benefits you offer? Yes. We provide full medical and dental coverage, a pension plan, and a three-week holiday per year.', "That's very generous. When is the position available?", "We're hoping the successful applicant can start at the beginning of next month. We'll finish our interviews tomorrow and make a decision by the weekend. We'll contact you next week. Thank you very much. It's been a pleasure meeting you. I hope to hear from you soon. Thanks for coming in to see us, Missus Stevens.", 'Ellie.']
# Hello, Mrs. Stevens. My name is Jane Phillips. I'm the Personnel director. I'm pleased to meet you. Please have a seat. Thank you. According to your resume, you have several years of office experience. Yes, I've had over 10 years experience. Tell me about your qualifications. I can type over 100 words per minute. I'm proficient in many computer programs. I have excellent interpersonal skills. I am well organized and I'm a very fast learner. I see that you have excellent references. Do you have any questions about the position? Yes. What are the responsibilities in this position? We're looking for someone to supervise 2 office clerks, handle all the correspondence, arrange meetings and manage the front office. Have you had any supervisory experience? Yes, I supervised 3 administrators in my last position. What are the office hours, Mrs. Phillips? 8:30 to 4:30 with an hour off for lunch. What are your salary expectations, Missus Stevens, I expect to be paid the going rate for this type of position. Can you tell me about the benefits you offer? Yes. We provide full medical and dental coverage, a pension plan, and a three-week holiday per year. That's very generous. When is the position available? We're hoping the successful applicant can start at the beginning of next month. We'll finish our interviews tomorrow and make a decision by the weekend. We'll contact you next week. Thank you very much. It's been a pleasure meeting you. I hope to hear from you soon. Thanks for coming in to see us, Missus Stevens. Ellie.
# Word Error Rate (WER): 4.62%
